# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import glob

# %%
def pre_process(tempImg, target_shape):
  plt.imshow(Image.open(tempImg))
  plt.show()
  temp = image.load_img(tempImg, target_size=target_shape)
  temp = np.array(temp)
  temp = np.expand_dims(temp, axis=0)
  return temp

# %%
def predict(img):
  print(f"SpeedBreaker: {model.predict(img)[0][0]*100}%")

# %%
model = tf.keras.models.load_model("E:\\Harshvardhan\\modelTrained1\\modelTrained1");
# Out:
# WARNING:tensorflow:SavedModel saved prior to TF 2.5 detected when loading Keras model. Please ensure that you are saving the model with model.save() or tf.keras.models.save_model(), *NOT* tf.saved_model.save(). To confirm, there should be a file named "keras_metadata.pb" in the SavedModel directory.

# %%
path_of_dir = "E:\\Harshvardhan\\Prediction\\"

# %%
for img in glob.glob(path_of_dir + "*.jpg"):
  predict(pre_process(img, [350, 350]))
  input("Press Enter to continue....")
# Out:
# SpeedBreaker: 0.0%
# SpeedBreaker: 0.0%
# SpeedBreaker: 0.0%
# SpeedBreaker: 0.0%
# SpeedBreaker: 0.0%
# SpeedBreaker: 0.0%
# SpeedBreaker: 0.0%
# SpeedBreaker: 0.0%
# SpeedBreaker: 0.0%
# SpeedBreaker: 0.0%
# SpeedBreaker: 100.0%
# SpeedBreaker: 100.0%
# SpeedBreaker: 100.0%
# SpeedBreaker: 100.0%
# SpeedBreaker: 100.0%
# SpeedBreaker: 100.0%
# SpeedBreaker: 100.0%
# SpeedBreaker: 100.0%
# SpeedBreaker: 100.0%
